# %% [markdown]
# ### Open Street Service Notebook
#
# Coded up with help of Chatgpt

# %% [markdown]
# ### How to encode the info
#
# How are we going to use this data?
#
# searching for places within the 1km radius of the house
#
# Need to be able to get the coords of the place so can work out distance + route(?) by car to both train station and CBD +
# - Train stations
# - CBD
# - parks
# - hosptials
# - supermarkets
# - schools
# - shopping districts
#
#
#
# - get a rough estimate for the amount of each within the 1km radius (just a count)
# - Also only print off/ Store the information of the places with either the coords or the address...

# %%
# Melbourne CBD Coords (LAT, LONG)

coords_cbd = [-37.8124, 144.9623]
import csv

# %% [markdown]
# # Build Functions
#
# 1.the get_coordinates() outputs the coordinates for every input of address
#
# 2.the find_nearby_locations outputs the nearby(1km) amentities for every input of address coordinates

# %%
from geopy.geocoders import Nominatim
import requests
import folium

def get_coordinates(address):
    geolocator = Nominatim(user_agent="myGeocoder")
    location = geolocator.geocode(address)
    return (location.latitude, location.longitude)


def find_nearby_locations(lat, lon, location_type):
    tags = {
        "schools": '["amenity"="school"]',
        "parks": '["leisure"="park"]',
        "supermarkets": '["shop"="supermarket"]',
        "shopping_districts": '["shop"="mall"]',
        "train_stations": '["railway"="station"]',
        "hospitals": '["amenity"="hospital"]'
    }
    
    query = f"""
    [out:json];
    (
      node{tags[location_type]}(around:1000,{lat},{lon});
      way{tags[location_type]}(around:1000,{lat},{lon});
      relation{tags[location_type]}(around:1000,{lat},{lon});
    );
    out body;
    """
    response = requests.get('http://overpass-api.de/api/interpreter', params={'data': query})
    data = response.json()
    return data['elements']

# %% [markdown]
# ### Process each Location
#
# Note that has the assumption that the address of the places found are within the suburb and postcode
#
# This shows amenities address as much as it can

# %%
import re 

def process_locations(locations, address):
    
    pattern = r",\s*([A-Za-z\s]+)\s*VIC\s*(\d{4})"
    match = re.search(pattern, address)
    
    if match:
        suburb = match.group(1).strip()  # Suburb (e.g., Coburg)
        postcode = match.group(2).strip()  # Postcode (e.g., 3058)
    
    # Dictionary to store valid locations
    valid_locations = []
    
    for loc in locations:
        
        if 'tags' in loc:
            name = loc['tags'].get('name')
            location_lat = loc.get('lat')
            location_lon = loc.get('lon')

            # Get the address information from tags if available
            
            street_number = loc['tags'].get('addr:housenumber')
            street = loc['tags'].get('addr:street')
            postcode = loc['tags'].get('addr:postcode', postcode)
            suburb = loc['tags'].get('addr:suburb', suburb)
            # Construct the address
            address = f"{street_number} {street}, {suburb}, {postcode}" if street_number and street else None
            
            # Filter locations with either coordinates or address
            if (location_lat and location_lon) or address:
                valid_locations.append({
                    'name': name or "Unnamed Location",
                    'lat': location_lat,
                    'lon': location_lon,
                    'address': address
                })
    
    return valid_locations

# %% [markdown]
# # Random sampling
#
# max 500 properties from every suburb in the datasets we have

# %%
import pandas as pd

# Open the CSV file ( Chnage this with the full dataset?)
file_path = '../data/landing/properties_3046-3055.csv'

df = pd.read_csv(file_path)

# Extract postcodes
df.insert(0, 'Postcodes', df['Address'].apply(lambda x: x.split('VIC')[-1].strip()))

# Randomly select max 500 rows from each postcodes and build a dataframe 
df = df.groupby('Postcodes', group_keys=False).apply(lambda x: x.sample(min(len(x), 500)))
df.head()
# Out:
# 558
# /tmp/ipykernel_2468/3854572155.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby('Postcodes', group_keys=False).apply(lambda x: x.sample(min(len(x), 500)))

# %% [markdown]
# ### Get nearby amenitites for each property
#
# Using the randomly sampled dataframe and previously built function
#
# Output the coordinates for every found anmentity

# %%
import time
import pandas as pd
from json.decoder import JSONDecodeError

summary_list = []

# Build the filters of amenities
location_types = ["schools", "parks", "supermarkets", "shopping_districts", "train_stations", "hospitals"]

# Create an empty DataFrame with summary columns
summary_df = pd.DataFrame(columns=['Postcodes', 'Address', 'URLS', 'Latitude', 'Longitude', 'Location Type', 'Count', 'Location Name', 'Location Address', 'Location Latitude', 'Location Longitude'])

for index, row in df.iterrows():
    postcodes = row['Postcodes']
    address = row['Address']
    urls = row['URLS']
    lat = row['Latitude']
    lon = row['Longitude']

    summary = {}

    try:
        for location_type in location_types:
            try:
                locations = find_nearby_locations(lat, lon, location_type)
                
                # Check if locations are found and process them
                if locations:
                    valid_locations = process_locations(locations, address)
                    summary[location_type] = {
                        'count': len(locations),  
                        'locations': valid_locations  
                    }
                else:
                    print(f"No locations found for {location_type} at {address}")
            
            # Catch potential JSON errors or other exceptions within find_nearby_locations
            except JSONDecodeError as e:
                print(f"JSON decoding error for {address} and location type {location_type}: {e}")
                continue

            # Add a delay of 1 second after processing each location_type
            time.sleep(1)

    except UnboundLocalError as e:
        print(f"Error processing {address}: {e}")
        continue  # Skip to the next iteration if there's an error

    # Add CBD and its summary as an individual amenity for every property
    summary_df = pd.concat([summary_df, pd.DataFrame([{
        'Postcodes': postcodes,
        'Address': address,
        'URLS': urls,
        'Latitude': lat,
        'Longitude': lon,
        'Location Type': 'CBD',  # Example row
        'Count': '1',
        'Location Name': 'CBD',
        'Location Address': '',
        'Location Latitude': '-37.8124',
        'Location Longitude': '144.9623'
    }])], ignore_index=True)

    # Add the summary of found nearby amenities for every property 
    for location_type, counts in summary.items():
        count = counts['count']
        for loc in counts['locations']:
            summary_df = pd.concat([summary_df, pd.DataFrame([{
                'Postcodes': postcodes,
                'Address': address,
                'URLS': urls,
                'Latitude': lat,
                'Longitude': lon,
                'Location Type': location_type,
                'Count': count,
                'Location Name': loc['name'],
                'Location Address': loc['address'],
                'Location Latitude': loc['lat'],
                'Location Longitude': loc['lon']
            }])], ignore_index=True)

    # Add a delay of 1 second between processing each property
    time.sleep(1)
# Out:
# No locations found for shopping_districts at 1/44 Stanley Street, Glenroy VIC 3046
# No locations found for hospitals at 1/44 Stanley Street, Glenroy VIC 3046
# /tmp/ipykernel_2468/3315535522.py:50: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   summary_df = pd.concat([summary_df, pd.DataFrame([{
# No locations found for shopping_districts at 9/14 Salisbury Street, Glenroy VIC 3046
# No locations found for hospitals at 9/14 Salisbury Street, Glenroy VIC 3046
# No locations found for supermarkets at 34 Glen Street, Glenroy VIC 3046
# No locations found for shopping_districts at 34 Glen Street, Glenroy VIC 3046
# No locations found for hospitals at 34 Glen Street, Glenroy VIC 3046
# No locations found for shopping_districts at 64B Loongana Avenue, Glenroy VIC 3046
street, Brunswick West VIC 3055
# No locations found for shopping_districts at 5/1 Trenoweth Street, Brunswick West VIC 3055
# No locations found for train_stations at 5/1 Trenoweth Street, Brunswick West VIC 3055
# No locations found for hospitals at 5/1 Trenoweth Street, Brunswick West VIC 3055
# No locations found for shopping_districts at G17/12 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at G17/12 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at G17/12 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 20/508 Moreland Road, Brunswick West VIC 3055
# No locations found for train_stations at 20/508 Moreland Road, Brunswick West VIC 3055
# No locations found for hospitals at 20/508 Moreland Road, Brunswick West VIC 3055
# No locations found for shopping_districts at 612/5 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 612/5 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 612/5 Olive York Way, Brunswick West VIC 3055
# No locations found for supermarkets at 5/608 Moreland Road, Brunswick West VIC 3055
# No locations found for shopping_districts at 5/608 Moreland Road, Brunswick West VIC 3055
# No locations found for hospitals at 5/608 Moreland Road, Brunswick West VIC 3055
# No locations found for shopping_districts at 4/49 Daly Street, Brunswick West VIC 3055
# No locations found for train_stations at 4/49 Daly Street, Brunswick West VIC 3055
# No locations found for hospitals at 4/49 Daly Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 108/8 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 108/8 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 108/8 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 1/82 Hopetoun Avenue, Brunswick West VIC 3055
# No locations found for train_stations at 1/82 Hopetoun Avenue, Brunswick West VIC 3055
# No locations found for hospitals at 1/82 Hopetoun Avenue, Brunswick West VIC 3055
# No locations found for shopping_districts at 605/8 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 605/8 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 605/8 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at B207/12 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at B207/12 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at B207/12 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 27 McGregor Avenue, Brunswick West VIC 3055
# No locations found for train_stations at 27 McGregor Avenue, Brunswick West VIC 3055
# No locations found for hospitals at 27 McGregor Avenue, Brunswick West VIC 3055
# No locations found for shopping_districts at 2/8 Allard Street, Brunswick West VIC 3055
# No locations found for train_stations at 2/8 Allard Street, Brunswick West VIC 3055
# No locations found for hospitals at 2/8 Allard Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 107/8 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 107/8 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 107/8 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 404/3 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 404/3 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 404/3 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 512/3 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 512/3 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 512/3 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 2/460 Albion St, Brunswick West VIC 3055
# No locations found for train_stations at 2/460 Albion St, Brunswick West VIC 3055
# No locations found for hospitals at 2/460 Albion St, Brunswick West VIC 3055
# No locations found for shopping_districts at 410/8 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 410/8 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 410/8 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 9/550 Moreland Road, Brunswick West VIC 3055
# No locations found for train_stations at 9/550 Moreland Road, Brunswick West VIC 3055
# No locations found for hospitals at 9/550 Moreland Road, Brunswick West VIC 3055
# No locations found for shopping_districts at 17 Henderson Street, Brunswick West VIC 3055
# No locations found for train_stations at 17 Henderson Street, Brunswick West VIC 3055
# No locations found for hospitals at 17 Henderson Street, Brunswick West VIC 3055
# No locations found for shopping_districts at G04/5 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at G04/5 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at G04/5 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at G07/2-4 Murray Street, Brunswick West VIC 3055
# No locations found for train_stations at G07/2-4 Murray Street, Brunswick West VIC 3055
# No locations found for hospitals at G07/2-4 Murray Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 514/8 Olive York Way, Brunswick West VIC 3055
# No locations found for train_stations at 514/8 Olive York Way, Brunswick West VIC 3055
# No locations found for hospitals at 514/8 Olive York Way, Brunswick West VIC 3055
# No locations found for shopping_districts at 4/12 Allard Street, Brunswick West VIC 3055
# No locations found for train_stations at 4/12 Allard Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 4/180A Melville Road, Brunswick West VIC 3055
# No locations found for train_stations at 4/180A Melville Road, Brunswick West VIC 3055
# No locations found for hospitals at 4/180A Melville Road, Brunswick West VIC 3055
# No locations found for shopping_districts at 5/30 Mclean Street, Brunswick West VIC 3055
# No locations found for train_stations at 5/30 Mclean Street, Brunswick West VIC 3055
# No locations found for hospitals at 5/30 Mclean Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 114/3 Duggan Street, Brunswick West VIC 3055
# No locations found for train_stations at 114/3 Duggan Street, Brunswick West VIC 3055
# No locations found for hospitals at 114/3 Duggan Street, Brunswick West VIC 3055
# No locations found for shopping_districts at 4/47 Waxman Parade, Brunswick West VIC 3055
# No locations found for train_stations at 4/47 Waxman Parade, Brunswick West VIC 3055
# No locations found for hospitals at 4/47 Waxman Parade, Brunswick West VIC 3055
# No locations found for shopping_districts at 4/43 Wales Street, Brunswick West VIC 3055
# No locations found for train_stations at 4/43 Wales Street, Brunswick West VIC 3055
# No locations found for hospitals at 4/43 Wales Street, Brunswick West VIC 3055

# %%
rows_without_none = summary_df.dropna()

# # Save the updated data to a new CSV file 
file_path_output = '../data/raw/properties_stats-3046-3055.csv'

rows_without_none.to_csv(file_path_output, index=False)

# %% [markdown]
# # Fix
# For amentities missing the corrdinates,using the geopy to fix
#
# But their are still some minor errors
#
# Output a fixed properties_stats.csv

# %%
import pandas as pd

from geopy.geocoders import Nominatim
import time

summary_df = pd.read_csv("../data/raw/properties_stats-3046-3055.csv")

# Initialize the geolocator
geolocator = Nominatim(user_agent="geoapi")

locations_retrieved = {}

# Build another Function to get the latitude and longitude from an address,and handle the errors
def get_lat_lon(address):
    try:
        location = geolocator.geocode(address)
        if location:
            locations_retrieved[address] = [location.latitude, location.longitude]

            return location.latitude, location.longitude
        
        else:
            return None, None
    except:
        return None, None

# Iterate through the rows and fill missing lat/lon
for idx, row in summary_df.iterrows():
    if pd.isnull(row['Location Latitude']) or pd.isnull(row['Location Longitude']):
        
        if row['Location Address'] in locations_retrieved.keys(): 
            
            lat = locations_retrieved[address][0]
            lon = locations_retrieved[address][1]
            
            summary_df.at[idx, 'Location Latitude'] = lat
            summary_df.at[idx, 'Location Longitude'] = lon
            
        else: 
            print(f"Trying {row['Location Address']}")
            
            print(locations_retrieved)
            
            lat, lon = get_lat_lon(row['Location Address'])
            summary_df.at[idx, 'Location Latitude'] = lat
            summary_df.at[idx, 'Location Longitude'] = lon
            
            time.sleep(3)  # Sleep to avoid overwhelming the API

# Save the updated data to a new CSV file 
file_path_output = '../data/raw/properties_stats-3046-3055.csv'

summary_df.to_csv(file_path_output, index=False)
# Out:
# Trying 23-33 Willett Avenue, Glenroy, 3046
# {}
# Trying 69 North Street, Glenroy, 3046
# {}
# Trying 69 North Street, Glenroy, 3046
# {}
# Trying 2-10 Pascoe Street, Hadfield, 3046
# {}
# Trying 45 Morell Street, Hadfield, 3046
# {}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 48
#      45             summary_df.at[idx, 'Location Latitude'] = lat
#      46             summary_df.at[idx, 'Location Longitude'] = lon
# ---> 48             time.sleep(3)  # Sleep to avoid overwhelming the API
#      50 # Save the updated data to a new CSV file
#      51 file_path_output = '../data/raw/properties_stats-3046-3055.csv'
#
# KeyboardInterrupt:
