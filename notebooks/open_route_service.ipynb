# %% [markdown]
# ### Notebook for Openroute service testings
#
# From the summary_df.csv,which summaries coordinates for every nearby amentity for every property;
#
# Calculate the Travel Distance, Travel Time take to amentities
#
# Also get the Average ,including the average counts for each suburb based on the calculation
#
# Debugged with Chatgpt

# %%
import openrouteservice as ors
import folium 
import json
import csv
import time

# %%
# Note you have to create an account and get your own personal API key
client = ors.Client(key = "")

# %%
# Open the csv and process for every row of address

# Use the filepath of whatever property stats 
file_path = '../data/raw/properties_stats-3046-3055.csv'

with open(file_path, mode='r', newline='', encoding='utf-8') as csv_file:
    reader = csv.DictReader(csv_file)
    rows = list(reader)

    # Add new 'Travel Time (minutes)' and 'Travel Distance (km)' columns to the header
    fieldnames = reader.fieldnames + ['Travel Time (minutes)', 'Travel Distance (km)']

    # Iterate over each row and calculate travel time and distance, update the CSV in place
    with open(file_path, mode='w', newline='', encoding='utf-8') as updated_csv_file:
        writer = csv.DictWriter(updated_csv_file, fieldnames=fieldnames)
        writer.writeheader()

        for row in rows:
            try:
                # Get coordinates and calculate travel time and distance
                lat1, lon1 = float(row['Latitude']), float(row['Longitude'])
                lat2, lon2 = float(row['Location Latitude']), float(row['Location Longitude'])
                coords = [[lon1, lat1], [lon2, lat2]]

                # Call OpenRouteService API to get route information
                route = client.directions(coordinates=coords, profile='driving-car', format='geojson')
                
                # Extract travel time in minutes
                travel_time_minutes = route['features'][0]['properties']['summary']['duration'] / 60
                
                # Extract travel distance in kilometers
                travel_distance_km = route['features'][0]['properties']['summary']['distance'] / 1000

                # Update the row with travel time and distance
                row['Travel Time (minutes)'] = f"{travel_time_minutes:.2f}"
                row['Travel Distance (km)'] = f"{travel_distance_km:.2f}"

                print(f"Processed travel time and distance for {row['Address']} to {row['Location Name']}: {travel_time_minutes:.2f} minutes, {travel_distance_km:.2f} km")

            except Exception as e:
                print(f"Error processing row {row['Address']} to {row['Location Name']}: {e}")
                row['Travel Time (minutes)'] = 'Error'
                row['Travel Distance (km)'] = 'Error'

            # Write updated row with the new columns
            writer.writerow(row)
            time.sleep(2)
# Out:
# Processed travel time and distance for 1/44 Stanley Street, Glenroy VIC 3046 to Glenroy West Primary School: 2.82 minutes, 1.20 km
# Processed travel time and distance for 1/44 Stanley Street, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 2.83 minutes, 1.25 km
# Processed travel time and distance for 1/44 Stanley Street, Glenroy VIC 3046 to Bridget Shortell Reserve: 3.01 minutes, 1.06 km
# Processed travel time and distance for 1/44 Stanley Street, Glenroy VIC 3046 to Coles: 2.85 minutes, 1.01 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Glenroy West Primary School: 4.29 minutes, 1.64 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Glenroy Central Primary School: 2.48 minutes, 0.84 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Glenroy Private: 3.02 minutes, 1.36 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Corpus Christi Primary School: 1.41 minutes, 0.53 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Glenroy Specialist School: 0.78 minutes, 0.30 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Glenroy Secondary College: 3.29 minutes, 1.57 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Bridget Shortell Reserve: 1.66 minutes, 0.63 km
# Processed travel time and distance for 9/14 Salisbury Street, Glenroy VIC 3046 to Coles: 2.55 minutes, 0.87 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Glenroy Central Primary School: 1.81 minutes, 0.62 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Glenroy Private: 1.61 minutes, 0.52 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Corpus Christi Primary School: 1.87 minutes, 0.86 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Glenroy Specialist School: 1.56 minutes, 0.81 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Glenroy Secondary College: 1.88 minutes, 0.66 km
# Processed travel time and distance for 34 Glen Street, Glenroy VIC 3046 to Bridget Shortell Reserve: 2.48 minutes, 1.38 km
# Processed travel time and distance for 64B Loongana Avenue, Glenroy VIC 3046 to Glenroy West Primary School: 3.00 minutes, 0.80 km
# Processed travel time and distance for 64B Loongana Avenue, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 1.91 minutes, 0.48 km
# Processed travel time and distance for 22 Glenroy Road, Glenroy VIC 3046 to Westbreen Primary School: 1.91 minutes, 1.40 km
# Processed travel time and distance for 22 Glenroy Road, Glenroy VIC 3046 to Glenroy Central Primary School: 2.42 minutes, 1.28 km
# Processed travel time and distance for 22 Glenroy Road, Glenroy VIC 3046 to Belle Vue Park Primary School: 3.08 minutes, 1.56 km
# Processed travel time and distance for 22 Glenroy Road, Glenroy VIC 3046 to Glenroy Secondary College: 1.51 minutes, 0.83 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Glenroy West Primary School: 2.89 minutes, 1.12 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 2.91 minutes, 1.17 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Glenroy Central Primary School: 2.03 minutes, 0.90 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Corpus Christi Primary School: 1.48 minutes, 0.63 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Glenroy Specialist School: 2.55 minutes, 1.26 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Glenroy Secondary College: 2.12 minutes, 1.19 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Bridget Shortell Reserve: 0.16 minutes, 0.10 km
# Processed travel time and distance for 90A Wheatsheaf Road, Glenroy VIC 3046 to Coles: 1.15 minutes, 0.35 km
# Processed travel time and distance for 3/26 Justin Avenue, Glenroy VIC 3046 to Glenroy Central Primary School: 3.53 minutes, 1.39 km
# Processed travel time and distance for 3/26 Justin Avenue, Glenroy VIC 3046 to Glenroy Private: 3.01 minutes, 0.99 km
# Processed travel time and distance for 3/26 Justin Avenue, Glenroy VIC 3046 to Belle Vue Park Primary School: 3.85 minutes, 1.46 km
# Processed travel time and distance for 3/26 Justin Avenue, Glenroy VIC 3046 to Corpus Christi Primary School: 3.56 minutes, 1.58 km
# Processed travel time and distance for 3/26 Justin Avenue, Glenroy VIC 3046 to Glenroy Secondary College: 2.62 minutes, 0.65 km
# Processed travel time and distance for 2/17 Eileen Street, Hadfield VIC 3046 to St Thomas More Primary School: 3.48 minutes, 1.16 km
# Processed travel time and distance for 2/17 Eileen Street, Hadfield VIC 3046 to Glenroy Secondary College: 0.90 minutes, 0.59 km
# Processed travel time and distance for 1/20 Eileen Street, Hadfield VIC 3046 to St Thomas More Primary School: 3.45 minutes, 1.15 km
# Processed travel time and distance for 1/20 Eileen Street, Hadfield VIC 3046 to Glenroy Secondary College: 0.87 minutes, 0.58 km
# Processed travel time and distance for 1/4 Dickinson Street, Hadfield VIC 3046 to St Thomas More Primary School: 5.00 minutes, 2.37 km
# Processed travel time and distance for 1/4 Dickinson Street, Hadfield VIC 3046 to IGA: 3.14 minutes, 0.99 km
# Processed travel time and distance for 4/26 Gladstone Parade, Glenroy VIC 3046 to Glenroy West Primary School: 1.25 minutes, 0.55 km
# Processed travel time and distance for 4/26 Gladstone Parade, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 1.08 minutes, 0.48 km
# Processed travel time and distance for 4/26 Gladstone Parade, Glenroy VIC 3046 to Corpus Christi Primary School: 2.89 minutes, 1.10 km
# Processed travel time and distance for 4/26 Gladstone Parade, Glenroy VIC 3046 to Bridget Shortell Reserve: 1.66 minutes, 0.59 km
# Processed travel time and distance for 4/26 Gladstone Parade, Glenroy VIC 3046 to Coles: 1.33 minutes, 0.54 km
# Processed travel time and distance for 41 Watt Avenue, Oak Park VIC 3046 to St Francis de Sales Primary School: 4.78 minutes, 1.50 km
# Error processing row 41 Watt Avenue, Oak Park VIC 3046 to Pascoe Vale Girls' Secondary College: 400 ({'error': {'code': 2004, 'message': 'Request parameters exceed the server configuration limits. The approximated route distance must not be greater than 6000000.0 meters.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1727914762543}})
# Processed travel time and distance for 4/29 East Street, Hadfield VIC 3046 to St Thomas More Primary School: 5.24 minutes, 2.48 km
# Processed travel time and distance for 2/128 Widford Street, Glenroy VIC 3046 to Glenroy Central Primary School: 2.68 minutes, 1.14 km
# Processed travel time and distance for 2/128 Widford Street, Glenroy VIC 3046 to Glenroy Private: 2.68 minutes, 0.74 km
# Processed travel time and distance for 2/128 Widford Street, Glenroy VIC 3046 to Corpus Christi Primary School: 2.30 minutes, 1.08 km
# Processed travel time and distance for 2/128 Widford Street, Glenroy VIC 3046 to Glenroy Specialist School: 1.98 minutes, 1.03 km
# Processed travel time and distance for 2/128 Widford Street, Glenroy VIC 3046 to Glenroy Secondary College: 3.32 minutes, 1.52 km
# Processed travel time and distance for 29 Pengana Avenue, Glenroy VIC 3046 to Glenroy West Primary School: 2.27 minutes, 0.62 km
# Processed travel time and distance for 29 Pengana Avenue, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus:
# Processed travel time and distance for 3/40 Sutherland Street, Hadfield VIC 3046 to St Thomas More Primary School: 3.75 minutes, 0.94 km
# Processed travel time and distance for 3/40 Sutherland Street, Hadfield VIC 3046 to Ilim College Glenroy Campus: 3.63 minutes, 1.58 km
# Processed travel time and distance for 37 Margaret Street, Oak Park VIC 3046 to St Francis de Sales Primary School: 1.11 minutes, 0.40 km
# Processed travel time and distance for 37 Margaret Street, Oak Park VIC 3046 to Oak Park Primary School: 2.52 minutes, 1.14 km
# Processed travel time and distance for 57 West St, Hadfield VIC 3046 to St Thomas More Primary School: 3.54 minutes, 1.38 km
# Processed travel time and distance for 57 West St, Hadfield VIC 3046 to Glenroy Secondary College: 0.96 minutes, 0.80 km
# Processed travel time and distance for 4/105 Vincent Street, Oak Park VIC 3046 to St Francis de Sales Primary School: 4.06 minutes, 1.40 km
# Processed travel time and distance for 4/105 Vincent Street, Oak Park VIC 3046 to Oak Park Primary School: 2.57 minutes, 0.64 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to St Francis de Sales Primary School: 1.61 minutes, 1.10 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Glenroy West Primary School: 1.95 minutes, 1.02 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 1.96 minutes, 1.07 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Glenroy Central Primary School: 3.84 minutes, 1.87 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Corpus Christi Primary School: 3.29 minutes, 1.60 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Bridget Shortell Reserve: 2.06 minutes, 1.08 km
# Processed travel time and distance for 14 Chapman Avenue, Glenroy VIC 3046 to Coles: 2.13 minutes, 1.09 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Glenroy West Primary School: 0.84 minutes, 0.39 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Penola Catholic College Glenroy Campus: 1.64 minutes, 0.59 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Corpus Christi Primary School: 3.29 minutes, 1.20 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Glenroy Specialist School: 4.36 minutes, 1.83 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Bridget Shortell Reserve: 2.06 minutes, 0.68 km
# Processed travel time and distance for 1/77 Chapman Avenue, Glenroy VIC 3046 to Coles: 1.68 minutes, 0.65 km
# Processed travel time and distance for 316/2 Bailey Crescent, Oak Park VIC 3046 to St Francis de Sales Primary School: 1.28 minutes, 0.45 km
# Processed travel time and distance for 316/2 Bailey Crescent, Oak Park VIC 3046 to Oak Park Primary School: 2.69 minutes, 1.18 km
# Processed travel time and distance for 1/5 Daley Street, Glenroy VIC 3046 to Glenroy Private: 2.57 minutes, 0.64 km
# Processed travel time and distance for 1/5 Daley Street, Glenroy VIC 3046 to Belle Vue Park Primary School: 3.27 minutes, 0.82 km
# Processed travel time and distance for 2/6 Gladstone Parade, Glenroy VIC 3046 to Glenroy Specialist School: 3.56 minutes, 1.48 km
# Processed travel time and distance for 2/6 Gladstone Parade, Glenroy VIC 3046 to Glenroy Secondary College: 3.13 minutes, 1.40 km
# Processed travel time and distance for 2/6 Gladstone Parade, Glenroy VIC 3046 to Bridget Shortell Reserve: 1.26 minutes, 0.33 km
# Processed travel time and distance for 2/6 Gladstone Parade, Glenroy VIC 3046 to Coles: 0.93 minutes, 0.28 km
# Processed travel time and distance for Unit 6/34 Grevillia Road, Oak Park VIC 3046 to St Francis de Sales Primary School: 3.69 minutes, 1.05 km
# Error processing row Unit 6/34 Grevillia Road, Oak Park VIC 3046 to Pascoe Vale Girls' Secondary College: 400 ({'error': {'code': 2004, 'message': 'Request parameters exceed the server configuration limits. The approximated route distance must not be greater than 6000000.0 meters.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1727915217686}})
# Processed travel time and distance for Unit 6/34 Grevillia Road, Oak Park VIC 3046 to Oak Park Primary School: 5.09 minutes, 1.79 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Glenroy Central Primary School: 2.02 minutes, 0.57 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Glenroy Private: 2.58 minutes, 0.88 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Corpus Christi Primary School: 2.33 minutes, 0.74 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Glenroy Specialist School: 2.81 minutes, 1.35 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Glenroy Secondary College: 0.79 minutes, 0.19 km
# Processed travel time and distance for 9/70-74 Cardinal Road, Glenroy VIC 3046 to Bridget Shortell Reserve: 2.60 minutes, 1.25 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Glenroy Central Primary School: 1.43 minutes, 0.54 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Glenroy Private: 3.52 minutes, 1.59 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Corpus Christi Primary School: 0.88 minutes, 0.27 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Glenroy Specialist School: 2.40 minutes, 1.25 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Glenroy Secondary College: 1.52 minutes, 0.82 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Bridget Shortell Reserve: 0.44 minutes, 0.27 km
# Processed travel time and distance for 2/168 Glenroy Road, Glenroy VIC 3046 to Coles: 1.34 minutes, 0.50 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Glenroy West Primary School: 4.54 minutes, 1.92 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Glenroy Central Primary School: 3.02 minutes, 1.45 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Glenroy Private: 3.39 minutes, 1.62 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Corpus Christi Primary School: 2.27 minutes, 1.14 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Glenroy Specialist School: 1.15 minutes, 0.56 km
# Processed travel time and distance for 2/38 Hartington Street, Glenroy VIC 3046 to Coles: 2.80 minutes, 1.16 km
# Processed travel time and distance for 3/72 Snell Grove, Oak Park VIC 3046 to St Francis de Sales Primary School: 4.06 minutes, 1.32 km
# Error processing row 3/72 Snell Grove, Oak Park VIC 3046 to Pascoe Vale Girls' Secondary College: 400 ({'error': {'code': 2004, 'message': 'Request parameters exceed the server configuration limits. The approximated route distance must not be greater than 6000000.0 meters.'}, 'info': {'engine': {'build_date': '2024-09-13T08:01:06Z', 'version': '8.1.3'}, 'timestamp': 1727915269280}})
# Processed travel time and distance for 3/72 Snell Grove, Oak Park VIC 3046 to Oak Park Primary School: 5.46 minutes, 2.06 km
# Processed travel time and distance for 2/53 May Street, Glenroy VIC 3046 to Belle Vue Park Primary School: 2.41 minutes, 0.60 km
# Processed travel time and distance for 2/53 May Street, Glenroy VIC 3046 to Ilim College Glenroy Campus: 5.05 minutes, 1.89 km
# Processed travel time and distance for 5/31 Station Road, Oak Park VIC 3046 to St Francis de Sales Primary School: 1.72 minutes, 0.77 km
# Processed travel time and distance for 5/31 Station Road, Oak Park VIC 3046 to Oak Park Primary School: 2.31 minutes, 0.79 km
# Processed travel time and distance for 3/63 May Street, Glenroy VIC 3046 to Belle Vue Park Primary School: 2.90 minutes, 0.72 km
# Processed travel time and distance for 3/63 May Street, Glenroy VIC 3046 to Ilim College Glenroy Campus: 5.53 minutes, 2.01 km
# Processed travel time and distance for 3/47 Cosmos Street, Glenroy VIC 3046 to Glenroy Central Primary School: 3.86 minutes, 1.75 km
# Processed travel time and distance for 3/47 Cosmos Street, Glenroy VIC 3046 to Glenroy Private: 2.94 minutes, 1.16 km
# Processed travel time and distance for 3/47 Cosmos Street, Glenroy VIC 3046 to Belle Vue Park Primary School: 2.65 minutes, 0.97 km
# Processed travel time and distance for 3/47 Cosmos Street, Glenroy VIC 3046 to Glenroy Secondary College: 3.32 minutes, 1.83 km
# Processed travel time and distance for 2/194 Daley Street, Glenroy VIC 3046 to Glenroy Private: 3.32 minutes, 1.24 km
# Processed travel time and distance for 2/194 Daley Street, Glenroy VIC 3046 to Corpus Christi Primary School: 2.57 minutes, 1.48 km
# Processed travel time and distance for 2/194 Daley Street, Glenroy VIC 3046 to Glenroy Specialist School: 1.45 minutes, 0.90 km
# Processed travel time and distance for 3/39 Elliott Avenue, Broadmeadows VIC 3047 to Meadows Primary School: 2.22 minutes, 0.67 km
# Processed travel time and distance for 3/39 Elliott Avenue, Broadmeadows VIC 3047 to Penola Catholic College: 3.67 minutes, 1.48 km
# Processed travel time and distance for 3/39 Elliott Avenue, Broadmeadows VIC 3047 to St Dominic's School: 3.67 minutes, 1.50 km
km
# Processed travel time and distance for 5/11 NICHOLAS Street, Broadmeadows VIC 3047 to Broadmeadows Shopping Centre: 5.95 minutes, 2.09 km
# Processed travel time and distance for 5/11 NICHOLAS Street, Broadmeadows VIC 3047 to Broadmeadows Hospital: 4.79 minutes, 1.49 km
# Processed travel time and distance for 1 Biltris Court, Broadmeadows VIC 3047 to Collingwood English Language School Broadmeadows Campus: 4.93 minutes, 2.06 km
# Processed travel time and distance for 1 Biltris Court, Broadmeadows VIC 3047 to Broadmeadows Valley Primary School: 4.29 minutes, 1.77 km
# Processed travel time and distance for 1 Biltris Court, Broadmeadows VIC 3047 to Penola Catholic College: 7.58 minutes, 2.67 km
# Processed travel time and distance for 1 Biltris Court, Broadmeadows VIC 3047 to Broadmeadows Special Developmental School: 4.53 minutes, 1.81 km
# Processed travel time and distance for 1 Biltris Court, Broadmeadows VIC 3047 to Broadmeadows Hospital: 3.98 minutes, 1.03 km
# Processed travel time and distance for 17 Stanhope Street, Broadmeadows VIC 3047 to Meadows Primary School: 2.57 minutes, 0.75 km
# Processed travel time and distance for 17 Stanhope Street, Broadmeadows VIC 3047 to Sirius College Eastmeadows Campus: 1.61 minutes, 0.40 km
# Processed travel time and distance for 17 Stanhope Street, Broadmeadows VIC 3047 to Hume Secondary College Blair Street Campus: 5.36 minutes, 2.01 km
# Processed travel time and distance for 17 Stanhope Street, Broadmeadows VIC 3047 to St Dominic's School: 3.21 minutes, 1.09 km
# Processed travel time and distance for 17 Stanhope Street, Broadmeadows VIC 3047 to Broadmeadows Primary School: 3.92 minutes, 1.59 km
# Processed travel time and distance for 1/22 Avalon Avenue, Broadmeadows VIC 3047 to Meadows Primary School: 3.23 minutes, 1.29 km
# Processed travel time and distance for 1/22 Avalon Avenue, Broadmeadows VIC 3047 to Penola Catholic College: 1.30 minutes, 0.35 km
# Processed travel time and distance for 1/22 Avalon Avenue, Broadmeadows VIC 3047 to St Dominic's School: 3.72 minutes, 1.08 km
# ...
# Error processing row 131 Pelham Street, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 131 Pelham Street, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 131 Pelham Street, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 131 Pelham Street, Carlton VIC 3053 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 131 Pelham Street, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 131 Pelham Street, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to North Melbourne IGA X-press: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/127 Leicester Street, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to Ozford College: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to Woolworths Metro: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 916/160 Victoria St, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to North Melbourne IGA X-press: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 408/50 Barry Street, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to North Melbourne IGA X-press: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 505/127 Leicester Street, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to Casa Iberica: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to ALDI: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to IGA X-press plus Liquor: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to Victorian Comprehensive Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 109/255 Cardigan Street, Carlton VIC 3053 to Peter MacCallum Cancer Centre: 403 ({'error': 'Quota exceeded'})
# Error processing row 30/1066 Lygon Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 7/767 Nicholson Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 7/767 Nicholson Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 1405/570 Lygon Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 1405/570 Lygon Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 114 Paterson Street, Carlton North VIC 3054 to The Source Bulk Foods: 403 ({'error': 'Quota exceeded'})
# Error processing row 114 Paterson Street, Carlton North VIC 3054 to Cheaper Buy Miles: 403 ({'error': 'Quota exceeded'})
# Error processing row 101/809 Rathdowne Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 101/809 Rathdowne Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 101/809 Rathdowne Street, Carlton North VIC 3054 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 26 Paterson Street, Princes Hill VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 26 Paterson Street, Princes Hill VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 534 Park Street, Princes Hill VIC 3054 to Sydney Road Community School: 403 ({'error': 'Quota exceeded'})
# Error processing row 534 Park Street, Princes Hill VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 534 Park Street, Princes Hill VIC 3054 to The Source Bulk Foods: 403 ({'error': 'Quota exceeded'})
# Error processing row 534 Park Street, Princes Hill VIC 3054 to Cheaper Buy Miles: 403 ({'error': 'Quota exceeded'})
# Error processing row 449 Station Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 449 Station Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 449 Station Street, Carlton North VIC 3054 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 8/1068 Lygon Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 904 Lygon Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 904 Lygon Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 904 Lygon Street, Carlton North VIC 3054 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 175 Amess Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 175 Amess Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 184 Mcilwraith Street, Princes Hill VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 184 Mcilwraith Street, Princes Hill VIC 3054 to The Source Bulk Foods: 403 ({'error': 'Quota exceeded'})
# Error processing row 184 Mcilwraith Street, Princes Hill VIC 3054 to Cheaper Buy Miles: 403 ({'error': 'Quota exceeded'})
# Error processing row 94 Princes Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 94 Princes Street, Carlton North VIC 3054 to Casa Iberica: 403 ({'error': 'Quota exceeded'})
# Error processing row 94 Princes Street, Carlton North VIC 3054 to King & Godfree: 403 ({'error': 'Quota exceeded'})
# Error processing row 94 Princes Street, Carlton North VIC 3054 to Vegetable Connection: 403 ({'error': 'Quota exceeded'})
# Error processing row 94 Princes Street, Carlton North VIC 3054 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 295 Amess Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 295 Amess Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 295 Amess Street, Carlton North VIC 3054 to Coles: 403 ({'error': 'Quota exceeded'})
# Error processing row 14/912 Drummond Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 14/912 Drummond Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/23 Holtom Street East, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/23 Holtom Street East, Carlton North VIC 3054 to The Source Bulk Foods: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/545-549 Nicholson Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/545-549 Nicholson Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/545-549 Nicholson Street, Carlton North VIC 3054 to Carlton Supermarket: 403 ({'error': 'Quota exceeded'})
# Error processing row 964 Drummond Street, Carlton North VIC 3054 to Foodworks: 403 ({'error': 'Quota exceeded'})
# Error processing row 964 Drummond Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 9/1068 Lygon Street, Carlton North VIC 3054 to TT Mart: 403 ({'error': 'Quota exceeded'})
# Error processing row 9/552 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 101/13 Cumming Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row LG06/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 460 Albion Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 1/1A Menzies Court, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row D215/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 1-5 Grantham street, Brunswick West VIC 3055 to Parkville College: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/28 Irvine Crescent, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 8/556 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 406/12 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 3/1 Duggan Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 401/1 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 103/1 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/9 McColl Court, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/9 Egginton Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 7/4a Duggan Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/465 Brunswick Road, Brunswick West VIC 3055 to Parkville College: 403 ({'error': 'Quota exceeded'})
# Error processing row 207/5 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 13/556 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 201/12 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row G17/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 6/490-492 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 14/448 Albion Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 308/1 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 2A Murray Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 50 Collier Crescent, Brunswick West VIC 3055 to Parkville College: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/14A Bent Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 5/1 Trenoweth Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row G17/12 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 20/508 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 612/5 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 108/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 1/82 Hopetoun Avenue, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 605/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row B207/12 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 27 McGregor Avenue, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 107/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 404/3 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 512/3 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 2/460 Albion St, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 410/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 9/550 Moreland Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 17 Henderson Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row G04/5 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row G07/2-4 Murray Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 514/8 Olive York Way, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 4/180A Melville Road, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 5/30 Mclean Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 114/3 Duggan Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 4/47 Waxman Parade, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})
# Error processing row 4/43 Wales Street, Brunswick West VIC 3055 to IGA: 403 ({'error': 'Quota exceeded'})

# %% [markdown]
# # Get the Average For Suburbs
#
# Output the aerage count,travel time and distance in every suburb

# %%
import pandas as pd

# Load the CSV file
df_suburb = pd.read_csv(file_path)

# Count the amentities for every property 
for i in range(len(df_suburb) - 1):
    # Compare the current row with the next row for the specified columns
    if (df_suburb.loc[i, 'Postcodes'] == df_suburb.loc[i+1, 'Postcodes'] and 
        df_suburb.loc[i, 'Address'] == df_suburb.loc[i+1, 'Address'] and
        df_suburb.loc[i, 'Location Type'] == df_suburb.loc[i+1, 'Location Type']):
        # Set the 'Count' of the next row to 0 if the condition is met
        df_suburb.loc[i+1, 'Count'] = 0

df_suburb['Travel Distance (km)'] = pd.to_numeric(df_suburb['Travel Distance (km)'], errors='coerce')

# Delete rows where "Travel Distance (km)" is too large(than 3km) to avoid huge bias
df_suburb = df_suburb[df_suburb['Travel Distance (km)'] <= 3]

# %%
import pandas as pd

# Convert 'Travel Distance (km)' and 'Travel Time (minutes)' to numeric, handling errors
df_suburb['Travel Distance (km)'] = pd.to_numeric(df_suburb['Travel Distance (km)'], errors='coerce')
df_suburb['Travel Time (minutes)'] = pd.to_numeric(df_suburb['Travel Time (minutes)'], errors='coerce')

# Calculate unique address counts per postcode
address_count_by_postcode = df_suburb.groupby('Postcodes')['Address'].nunique().reset_index()
address_count_by_postcode.columns = ['Postcodes', 'Unique Address Count']

# get the total count, average travel distance, and average travel time
df_suburb_postcodes = df_suburb.groupby(['Postcodes', 'Location Type']).agg(
    Count=('Count', 'sum'),
    Average_Distance=('Travel Distance (km)', 'mean'),
    Average_Time=('Travel Time (minutes)', 'mean')
).reset_index()

# Merge with address count to calculate average count
df_suburb_postcodes  = pd.merge(df_suburb_postcodes , address_count_by_postcode, on='Postcodes')
df_suburb_postcodes ['Average Count'] = df_suburb_postcodes ['Count'] / df_suburb_postcodes ['Unique Address Count']

# Drop unnecessary columns for final output
final_average_data = df_suburb_postcodes [['Postcodes', 'Location Type', 'Count', 'Average Count', 'Average_Distance', 'Average_Time']]

file_output_path = '../data/raw/suburb_stats-3046-3055.csv'
final_average_data.to_csv(file_output_path,index=False)
